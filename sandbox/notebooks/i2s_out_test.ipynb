# %%
values = [4168687656, 4158873184, 4149517248, 4140650896, 4132249248, 4124450576, 4117222304, 4110587088, 4104527504, 4099142416, 4094406064, 4090332768, 4086955200, 4084222320, 4082192272, 4080877584, 4080268096, 4080360432, 4081159504, 4082673584, 4084861136, 4087774288, 4091353424, 4095604816, 4100515648, 4106110192, 4112297296, 4119092752, 4126475440, 4134367312, 4142965712, 4151965536]

import matplotlib.pyplot as plt

plt.plot([int.from_bytes(s.to_bytes(4, 'big'), byteorder='big', signed=True) for i, s in enumerate(values) if i % 2 == 0])
