# %%
import matplotlib.pyplot as plt
from math import *

pi2 = pi * 2

# Here I go not from sample rate, but from length to simplify plotting
len = 100
freq = 440
sr = freq * len
wave_len = sr / freq

sine = [sin(pi2 * x / wave_len) for x in range(len)]
square = [copysign(1, sin(pi2 * x / wave_len)) for x in range(len)]
triangle = [2.0 * abs(2.0 * (x / wave_len - floor(x / wave_len + 0.5))) - 1.0 for x in range(len)]
saw = [2.0 * (x / wave_len - floor(x / wave_len + 0.5)) for x in range(len)]
reverse_saw = [2.0 * (floor(x / wave_len + 0.5) - x / wave_len) for x in range(len)]

# plt.plot(sine, label='Sine')
# plt.plot(square, label='Square')
# plt.plot(triangle, label='Triangle')
# plt.plot(saw, label='Saw')
# plt.plot(reverse_saw, label='Reverse saw')
# plt.plot(list(map(lambda s: (s + 1.0) * (2 ** 32 - 1) / 2.0, sine)))

plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
