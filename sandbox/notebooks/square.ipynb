# %%
import matplotlib.pyplot as plt
import math

# def square(sr: int, freq: float, length: int):
#     result = [0.0] * length
#     for i in range(length):
#         result[i] = math.sign(math.pi * 2 * freq / sr)

sample_rate = 44100
freq = 100
length = 1000
# wave_len = sample_rate / freq

for x in range(length):
    plt.plot(x, math.copysign(1, math.sin(math.pi * 2 * x * freq / sample_rate)), 'ro')

plt.show()
