# %%
import matplotlib.pyplot as plt
import math

sample_rate = 44100
freq = 100
length = 1000
wave_len = sample_rate / freq
period = 1.0 / freq

saw = [2 * (x / wave_len - math.floor(x / wave_len + 0.5)) for x in range(length)]

# https://en.wikipedia.org/wiki/Sawtooth_wave
# for x in range(length):
#     t = x / freq * sample_rate
#     # plt.plot(x, 2 * (x / period - math.floor(0.5 + x / period)), 'ro')
#     plt.plot(x, , 'ro')

plt.plot(saw)

plt.show()
