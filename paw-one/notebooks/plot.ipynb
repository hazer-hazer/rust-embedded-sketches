# %%
import matplotlib.pyplot as plt

vals = open('./i2s.csv', 'r', encoding='utf8').read().split(',')[0:500:2]
vals = list(map(lambda val: int.from_bytes(int(val, 0).to_bytes(2, 'big', signed=True), 'big', signed=True), vals))

# vals = open('/mnt/c/Users/PYJOHN/Downloads/i2s.csv', 'r', encoding='utf8')
# vals = map(lambda val: int(val), vals.read().split(','))
# vals = list(vals)

# plt.plot([int.from_bytes(x.to_bytes(4, 'big'), 'big', signed=True) for i, x in enumerate(vals) if i % 2 == 0])

plt.plot(vals)
